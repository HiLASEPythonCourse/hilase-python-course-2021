# %%
import pandas as pd
import requests

# %% [markdown]
# ## US state population 2020

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population")

# %%
population = tables[0][[("State or territory", "State or territory"), ("Census population", "EstimatedJuly 1, 2020[8]")]].iloc[:52].drop(30).reset_index(drop=True)
population.columns = ["Territory", "Population"]
population.loc[51] = ["Puerto Rico", 3189086]
population.loc[52] = ["Northern Mariana Islands", 51433]
population.loc[53] = ["Guam", 168485]
population.Population = population.Population.astype("int")
population.to_csv("us_state_population.csv", index=False)
population
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-a2751b945537> in <module>
# ----> 1 population = tables[0][[("State or territory", "State or territory"), ("Census population", "EstimatedJuly 1, 2020[8]")]].iloc[:52].drop(30).reset_index(drop=True)
#       2 population.columns = ["Territory", "Population"]
#       3 population.loc[51] = ["Puerto Rico", 3189086]
#       4 population.loc[52] = ["Northern Mariana Islands", 51433]
#       5 population.loc[53] = ["Guam", 168485]
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1263             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1264
# -> 1265         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1266         return keyarr, indexer
#    1267
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1305             if missing == len(indexer):
#    1306                 axis_name = self.obj._get_axis_name(axis)
# -> 1307                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1308
#    1309             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index([('State or territory', 'State or territory'), ('Census population', 'EstimatedJuly 1, 2020[8]')], dtype='object')] are in the [columns]"

# %% [markdown]
# ## Laser incidents in 2019
#
# From https://www.faa.gov/about/initiatives/lasers/laws/.

# %%
response = requests.get("https://www.faa.gov/about/initiatives/lasers/laws/media/Laser_Report_2019_final.xlsx")
with open("laser_incidents_2019.xlsx", "wb") as xls_out:
    xls_out.write(response.content)

# %%
incidents = pd.read_excel("laser_incidents_2019.xlsx")

# %%
sorted(incidents["State"].unique())
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'DC',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Guam',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Marina Islands',
#  'Maryland',
#  'Massachusetts',
#  'Mexico',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Puerto Rico',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Teas',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'VA',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']
